# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/lena256.jpg')

print(img.shape)
gimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#plt.imshow(gimg, cmap='gray')
cv2_imshow(gimg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
M = cv2.getRotationMatrix2D((128, 128), 45, 1)
ourimg = cv2.warpAffine(gimg, M, (256, 256))
cv2_imshow(ourimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
print(M)
print(M.shape)
# Out:
# [[  0.70710678   0.70710678 -53.01933598]
#  [ -0.70710678   0.70710678 128.        ]]
# (2, 3)

# %%
M = np.float32([[1, 0, 100], [0, 1, 50]])
outimg = cv2.warpAffine(gimg, M, (256, 256))
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
M = cv2.getRotationMatrix2D((128, 128), -45, 1)
ourimg = cv2.warpAffine(gimg, M, (256, 256))
cv2_imshow(ourimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
M1 = np.float32([[1, 0, -128], [0, 1, -128]])
outimg1 = cv2.warpAffine(gimg, M1, (256, 256))
cv2_imshow(outimg1)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
M2 = cv2.getRotationMatrix2D((0, 0), -45, 1)
outimg2 = cv2.warpAffine(outimg1, M2, (256, 256))
cv2_imshow(outimg2)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
print(M2)
# Out:
# [[ 0.70710678 -0.70710678  0.        ]
#  [ 0.70710678  0.70710678  0.        ]]

# %%
M3 = np.float32([[1, 0, 128], [0, 1, 128]])
outimg3 = cv2.warpAffine(outimg2, M3, (256, 256))
cv2_imshow(outimg3)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
N1 = np.float32([[M1[0,0],M1[0,1],M1[0,2]], [M1[1,0],M1[1,1],M1[1,2]], [0,0,1]])
N2 = np.float32([[M2[0,0],M2[0,1],M2[0,2]], [M2[1,0],M2[1,1],M2[1,2]], [0,0,1]])
N3 = np.float32([[M3[0,0],M3[0,1],M3[0,2]], [M3[1,0],M3[1,1],M3[1,2]], [0,0,1]])
print(N3)
# Out:
# [[  1.   0. 128.]
#  [  0.   1. 128.]
#  [  0.   0.   1.]]

# %%
N4 = np.dot(N3,N2)
N5 = np.dot(N4,N1)
N6 = np.float32([[M5[0,0],M5[0,1],M5[0,2]], [M5[1,0],M5[1,1],M5[1,2]]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-446896309.py in <cell line: 0>()
#       1 N4 = np.dot(N3,N2)
#       2 N5 = np.dot(N4,N1)
# ----> 3 N6 = np.float32([[M5[0,0],M5[0,1],M5[0,2]], [M5[1,0],M5[1,1],M5[1,2]]])
#
# NameError: name 'M5' is not defined

# %%
outimg4 = cv2.warpAffine(gimg, N5, (256, 256))
cv2_imshow(outimg4)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-2056179606.py in <cell line: 0>()
# ----> 1 outimg4 = cv2.warpAffine(gimg, N5, (256, 256))
#       2 cv2_imshow(outimg4)
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/imgwarp.cpp:2729: error: (-215:Assertion failed) (M0.type() == CV_32F || M0.type() == CV_64F) && M0.rows == 2 && M0.cols == 3 in function 'warpAffine'
