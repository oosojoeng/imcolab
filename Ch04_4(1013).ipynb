# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/girl.jpg')

print(img.shape)
gimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#plt.imshow(gimg, cmap='gray')
cv2_imshow(gimg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
outimg = np.zeros(gimg.shape, dtype='uint8')

# %%
outimg = cv2.equalizeHist(gimg)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist = cv2.calcHist([gimg], [0], None, [256], [0, 256])
plt.plot(hist)

# %%
myHist = np.zeros((256,1), dtype=np.int32)

# %% [markdown]
# 히스토그램 만들기

# %%
for h in range(gimg.shape[0]):
  for w in range(gimg.shape[1]):
    myHist[outimg[h,w]] += 1

  plt.plot(myHist)

# %%
cumulHist = np.zeros((256,1), dtype=np.int32)

# %%
cumulHist[0] = myHist[0]
for i in range(1,256):
  cumulHist[i] = cumulHist[i-1] + myHist[i]

  plt.plot(cumulHist)

# %% [markdown]
# 히스토그램 평활화

# %%
equalHist = np.zeros((256,1), dtype=np.int32)

# %%
numOfPixel = gimg.shape[0] * gimg.shape[1]
equalHist = cumulHist / numOfPixel
equalHist = equalHist * 255

plt.plot(equalHist)

# %%
for h in range(gimg.shape[0]):
  for w in range(gimg.shape[1]):
    outimg[h,w] = equalHist[gimg[h,w]]

cv2_imshow(outimg)
# Out:
# /tmp/ipython-input-674100059.py:3: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   outimg[h,w] = equalHist[gimg[h,w]]
# <PIL.Image.Image image mode=L size=256x256>
