# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#img = cv2.imread('/content/gdrive/My Drive/IP/Images/girl.jpg')

print(img.shape)
gimg = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#plt.imshow(gimg, cmap='gray')
cv2_imshow(gimg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
hist = cv2.calcHist([gimg], [0], None, [256], [0, 256])
plt.plot(hist)
plt.show()

# %%
outimg = np.zeros(gimg.shape, dtype='uint8')

# %%
min = 0
max = 200

for h in range(gimg.shape[0]):
  for w in range(gimg.shape[1]):
    if gimg[h, w] < min:
      outimg[h, w] = 0
    elif gimg[h, w] > max:
      outimg[h, w] = 255
    else:
      val = np.int32(gimg[h, w] (max - min) * 255
      val = np.int32(val / (max - min))
      outimg[h, w] = val

  cv2_imshow(outimg)
# Out:
#   File "/tmp/ipython-input-1709811290.py", line 11
#     val = np.int32(gimg[h, w] - (max - min) * 255
#                   ^
# SyntaxError: '(' was never closed

# %%
hist2 = cv2.calcHist([outimg], [0], None, [256], [0, 256])
plt.plot(hist2)
plt.show()
